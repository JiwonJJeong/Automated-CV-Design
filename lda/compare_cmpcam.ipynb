# %% [markdown]
# # Analysis of CaM compact
# ## Comparison of all CaM states

# %%
import sys
import os
import pandas as pd
import numpy as np

# Add the lda directory to Python path
lda_path = os.path.join(os.getcwd(), 'lda')
if lda_path not in sys.path:
    sys.path.append(lda_path)

# Import the interactive pipeline functions
from pipeline_helper import run_interactive_pipeline, create_interactive_pipeline_configs, summarize_and_evaluate

# Import your existing data access module
from data_access import create_dataframe_factory, list_available_constructs_subconstructs

print("✅ Imports completed successfully!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 12
#       9     sys.path.append(lda_path)
#      11 # Import the interactive pipeline functions
# ---> 12 from pipeline_helper import run_interactive_pipeline, create_interactive_pipeline_configs, summarize_and_evaluate
#      14 # Import your existing data access module
#      15 from data_access import create_dataframe_factory, list_available_constructs_subconstructs
#
# File ~/gk-lab/Automated-CV-Design/lda/pipeline_helper.py:473
#     469         loadings[ld] = corrs.abs().sort_values(ascending=False).head(3).to_dict()
#     471     return loadings
# --> 473 import plotly.graph_objects as go
#     474 import numpy as np
#     475 import pandas as pd
#
# ModuleNotFoundError: No module named 'plotly'

# %%
data_dir = '/work/hdd/bfri/jjeong7/analysis_output/dist_maps'
constructs_dict, subconstructs_dict = list_available_constructs_subconstructs(base_dir=data_dir)

# Specific states of specific proteins
data_factory = create_dataframe_factory(
    base_dir=data_dir, 
    constructs=['calmodulin-compact'],
    apply_boundary_filter=True, # 🛠️ ACTIVATE TRANSFORMATION
    n_edge=3,
    min_frame=0,
)

# %%
# Create all possible pipeline combinations
configs = create_interactive_pipeline_configs()

# %%
print("🚀 Starting Interactive Pipeline Runner")
print("💡 Variance runs first, then feature selection, then dimensionality reduction")
print("⚙️  You'll set parameters for each phase")

# Use the pipeline runner
results, base_df = run_interactive_pipeline(data_factory, configs)
# Out:
# 🚀 Starting Interactive Pipeline Runner
# 💡 Variance runs first, then feature selection, then dimensionality reduction
# ⚙️  You'll set parameters for each phase
# Found cached result for VARIANCE (pipeline_cache/variance.pkl). Load? (Y/n):  y
# Loaded cached VARIANCE data.
# Shape: (90000, 426)
# Found cached result for FISHER_AMINO (pipeline_cache/fisher_amino.pkl). Load? (Y/n):  y
# Loaded cached FISHER_AMINO data.
# Shape: (90000, 14)
# Found cached result for CHI_SQ_AMINO (pipeline_cache/chi_sq_amino.pkl). Load? (Y/n):  y
# Loaded cached CHI_SQ_AMINO data.
# Shape: (90000, 7)
# Found cached result for MPSO (pipeline_cache/mpso.pkl). Load? (Y/n):  y
# Loaded cached MPSO data.
# Shape: (90000, 11)
# Found cached result for BPSO (pipeline_cache/bpso.pkl). Load? (Y/n):  y
# Loaded cached BPSO data.
# Shape: (90000, 22)
#
# ==================================================
# 🤖 AUTOMATED DIMENSIONALITY REDUCTION PHASE
# Found existing DR caches. Recompute ALL methods? (y/N):  n
# No further interaction required. Results will be saved automatically.
# ==================================================
# ⏩ Skipping bpso_to_flda (Already cached)
# ⏩ Skipping bpso_to_pca (Already cached)
# ⏩ Skipping bpso_to_zhlda (Already cached)
# ⏩ Skipping bpso_to_mhlda (Already cached)
# ⏩ Skipping bpso_to_gdhlda (Already cached)
# ⏩ Skipping mpso_to_flda (Already cached)
# ⏩ Skipping mpso_to_pca (Already cached)
# ⏩ Skipping mpso_to_zhlda (Already cached)
# ⏩ Skipping mpso_to_mhlda (Already cached)
# ⏩ Skipping mpso_to_gdhlda (Already cached)
# ⏩ Skipping fisher_amino_to_flda (Already cached)
# ⏩ Skipping fisher_amino_to_pca (Already cached)
# ⏩ Skipping fisher_amino_to_zhlda (Already cached)
# ⏩ Skipping fisher_amino_to_mhlda (Already cached)
# ⏩ Skipping fisher_amino_to_gdhlda (Already cached)
# ⏩ Skipping chi_sq_amino_to_flda (Already cached)
# ⏩ Skipping chi_sq_amino_to_pca (Already cached)
# ⏩ Skipping chi_sq_amino_to_zhlda (Already cached)
# ⏩ Skipping chi_sq_amino_to_mhlda (Already cached)
# ⏩ Skipping chi_sq_amino_to_gdhlda (Already cached)
#
# ✨ All automated pipelines complete.

# %%
if results and base_df is not None:
    summarize_and_evaluate(results, base_df)
# Out:
# 🏆 DIMENSIONALITY REDUCTION LEADERBOARD 🏆
# ====================================================================================================
# Rank  | Pipeline Name             | Fisher Score | Dims
# ----------------------------------------------------------------------------------------------------
# 1     | mpso_to_mhlda             | 0.1352       | 3
#       📉 Selection Stats: 0 numeric features available for mapping.
#       ↳ Info: No numeric survivors found for feature mapping.
# ----------------------------------------------------------------------------------------------------
# 2     | mpso_to_zhlda             | 0.1351       | 3
#       📉 Selection Stats: 0 numeric features available for mapping.
#       ↳ Info: No numeric survivors found for feature mapping.
# ----------------------------------------------------------------------------------------------------
# 3     | mpso_to_flda              | 0.1348       | 2
#       📉 Selection Stats: 0 numeric features available for mapping.
#       ↳ Info: No numeric survivors found for feature mapping.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 if results and base_df is not None:
# ----> 2     summarize_and_evaluate(results, base_df)
#
# File ~/ondemand/lda/pipeline_helper.py:485, in summarize_and_evaluate(results, original_df, corr_threshold)
#     483             visualize_cluster_biplot_3d(original_df, df, name, survivors=used_features)
#     484         elif len(ld_cols) == 2:
# --> 485             visualize_cluster_biplot(original_df, df, name, survivors=used_features)
#     486     print("-" * 100)
#     488 import gc
#
# NameError: name 'visualize_cluster_biplot' is not defined
